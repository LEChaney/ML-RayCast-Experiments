# %% [markdown]
# <a href="https://colab.research.google.com/github/LEChaney/ML-RayCast-Experiments/blob/master/FlappyBird_Experiment_Wrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/LEChaney/ML-RayCast-Experiments
# Out:
# Cloning into 'ML-RayCast-Experiments'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 61 (delta 18), reused 60 (delta 17), pack-reused 0
# Unpacking objects: 100% (61/61), done.

# %%
# Dependencies
# %tensorflow_version
# Out:
# Currently selected TF version: 1.x
# Available versions:
# * 1.x
# * 2.x

# %%
# %cd ML-RayCast-Experiments/DeepLearningFlappyBird/
# Out:
# /content/ML-RayCast-Experiments/DeepLearningFlappyBird

# %%
# !ls
# Out:
# assets	deep_q_network.py  game  images  LICENSE  logs_bird  README.md

# %%
# !python deep_q_network.py
# Out:
# Traceback (most recent call last):
#   File "deep_q_network.py", line 8, in <module>
#     import wrapped_flappy_bird as game
#   File "game/wrapped_flappy_bird.py", line 4, in <module>
#     import pygame
# ModuleNotFoundError: No module named 'pygame'

# %%
# !pip install pygame
# Out:
# ...
#      |████████████████████████████████| 11.4MB 30.9MB/s
# ...

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
import os
#import pygame
os.environ["SDL_VIDEODRIVER"] = "dummy"
#pygame.init()
# Out:
# (5, 1)

# %%
# !git clone https://github.com/LEChaney/ML-RayCast-Experiments
# %cd ML-RayCast-Experiments/DeepLearningFlappyBird/
# !python deep_q_network.py
# Out:
# Cloning into 'ML-RayCast-Experiments'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 85 (delta 34), reused 75 (delta 27), pack-reused 0
# Unpacking objects: 100% (85/85), done.
# /content/ML-RayCast-Experiments/DeepLearningFlappyBird/ML-RayCast-Experiments/DeepLearningFlappyBird/ML-RayCast-Experiments/DeepLearningFlappyBird/ML-RayCast-Experiments/DeepLearningFlappyBird/ML-RayCast-Experiments/DeepLearningFlappyBird
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ALSA lib confmisc.c:767:(parse_card) cannot find card '0'
# ALSA lib conf.c:4528:(_snd_config_evaluate) function snd_func_card_driver returned error: No such file or directory
# ALSA lib confmisc.c:392:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:4528:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ...
